# %%
df = spark.read.format("csv").option("header","true").load("abfss://ElectricVehical_DataAnalysis@onelake.dfs.fabric.microsoft.com/EV_Raw_Lakehouse.Lakehouse/Files/electric_vehicles_dataset.csv")
# Out:
# StatementMeta(, 38f1c771-e343-4c8b-bd3c-e490e5395558, 3, Finished, Available, Finished, False)

# %%
df.write.format("delta").saveAsTable("dbo.ev_data")
# Out:
# StatementMeta(, 38f1c771-e343-4c8b-bd3c-e490e5395558, 4, Finished, Available, Finished, False)
